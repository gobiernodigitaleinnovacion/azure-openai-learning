# %%
# Procesamiento de Documentos con Azure OpenAI
import sys
import os
from pathlib import Path

# Agregar el directorio raíz al path
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from src.procesador_documentos import ProcesadorDocumentos

# Crear instancia del procesador
procesador = ProcesadorDocumentos()

# Ejemplo de documento para extraer datos
texto_documento = """
Informe de Ventas - Región Norte
Fecha: 15 de Noviembre 2023
Cliente: Empresa ABC
Producto: Software de Gestión
Cantidad: 5 licencias
Precio unitario: $1,200
Total: $6,000
Términos de pago: 30 días
"""

# Ejemplo de contrato
texto_contrato = """
CONTRATO DE SERVICIOS
Entre las partes:
- Proveedor: Servicios Tech SA
- Cliente: Empresa ABC
- Duración: 12 meses
- Valor mensual: $5,000
- Servicios incluidos: Mantenimiento, Soporte 24/7
"""

# Ejemplo de factura
texto_factura = """
FACTURA
No: FAC-2023-001
Fecha: 20 de Noviembre 2023

EMISOR:
Servicios Tech SA
RFC: TECH231120ABC

RECEPTOR:
Empresa ABC
RFC: ABC850101XYZ

CONCEPTOS:
1. Licencia Software Gestión x 5
   Precio unitario: $1,200
   Subtotal: $6,000

2. Servicio Implementación
   Precio: $2,000

Subtotal: $8,000
IVA (16%): $1,280
Total: $9,280
"""

# Procesar documentos
print("1. Extracción de Datos Estructurados:")
datos = procesador.extraer_datos_estructurados(texto_documento)
print(datos)

print("\n2. Análisis de Contrato:")
analisis = procesador.analizar_contrato(texto_contrato)
print(analisis)

print("\n3. Procesamiento de Factura:")
datos_factura = procesador.procesar_factura(texto_factura)
print(datos_factura)

try:
    print("\n4. Resumen Ejecutivo del Contrato:")
    resumen = procesador.generar_resumen_ejecutivo(texto_contrato)
    print(resumen)
except AttributeError:
    print("Método 'generar_resumen_ejecutivo' no implementado.")

try:
    print("\n5. Puntos Clave de la Factura:")
    puntos_clave = procesador.identificar_puntos_clave(texto_factura)
    print(puntos_clave)
except AttributeError:
    print("Método 'identificar_puntos_clave' no implementado.")
# Out:
# 1. Extracción de Datos Estructurados:
# ```json
# {
#   "informe_ventas": {
#     "region": "Norte",
#     "fecha": "15 de Noviembre 2023",
#     "cliente": "Empresa ABC",
#     "producto": {
#       "nombre": "Software de Gestión",
#       "cantidad": 5,
#       "precio_unitario": 1200,
#       "total": 6000
#     },
#     "terminos_de_pago": "30 días"
#   }
# }
# ```
#
# 2. Análisis de Contrato:
# Resumen y análisis del contrato de servicios:
#
# 1. **Partes Involucradas:**
#    - **Proveedor:** Servicios Tech SA, quien es responsable de proporcionar los servicios estipulados.
#    - **Cliente:** Empresa ABC, que contratará y hará uso de los servicios brindados por el proveedor.
#
# 2. **Duración del Contrato:**
#    - El acuerdo tiene una vigencia de 12 meses, lo que establece el compromiso de ambas partes por un año completo.
#
# 3. **Valor del Contrato:**
#    - El cliente deberá pagar al proveedor un monto mensual de $5,000. Esto constituye una obligación financiera que la Empresa ABC debe cumplir puntualmente para recibir los servicios.
#
# 4. **Servicios Incluidos:**
#    - **Mantenimiento:** Esto puede implicar revisiones periódicas, actualización de equipos o sistemas, reparación de fallos, etc.
#    - **Soporte 24/7:** El proveedor garantiza disponibilidad completa para atender cualquier incidente o consulta las 24 horas del día, los 7 días de la semana, asegurando asistencia continua al cliente.
#
# 5. **Cláusulas Importantes y Obligaciones:**
#    - **Pago a Tiempo:** El cliente está obligado a realizar los pagos de manera puntual cada mes para evitar incumplimientos.
#    - **Calidad de Servicios:** El proveedor debe asegurar que los servicios de mantenimiento y soporte se realicen de manera efectiva, cumpliendo con los estándares usuales de calidad en la industria.
#    - **Términos de Renovación o Finalización:** Aunque no se detalla en el resumen del contrato, usualmente este tipo de acuerdos incluyen términos sobre la renovación automática o renegociación al finalizar el período de 12 meses, así como las condiciones bajo las cuales se puede dar por terminado el servicio antes del plazo acordado.
#    - **Confidencialidad y Protección de Datos:** Aunque no se menciona explícitamente, es común incluir cláusulas que protejan la información compartida entre ambas partes durante la relación contractual.
#
# Este análisis proporciona un entendimiento básico del contrato, destacando las obligaciones y expectativas principales de cada parte. Es importante revisar el documento completo para obtener detalles específicos adicionales.
#
# 3. Procesamiento de Factura:
# Aquí está un resumen con la información relevante extraída de la factura:
#
# **Información de la Factura:**
# - Número de Factura: FAC-2023-001
# - Fecha de Emisión: 20 de Noviembre 2023
#
# **Datos del Emisor:**
# - Nombre: Servicios Tech SA
# - RFC: TECH231120ABC
#
# **Datos del Receptor:**
# - Nombre: Empresa ABC
# - RFC: ABC850101XYZ
#
# **Conceptos Detallados:**
# 1. **Licencia Software Gestión x 5**
#    - Precio Unitario: $1,200
#    - Subtotal: $6,000
#
# 2. **Servicio Implementación**
#    - Precio Total: $2,000
#
# **Montos Totales:**
# - Subtotal General: $8,000
# - IVA (16%): $1,280
# - Total a Pagar: $9,280
#
# **Fechas:**
# - Fecha de la Factura: 20 de Noviembre 2023
#
# Estos datos abarcan los aspectos esenciales de la factura, incluyendo cálculos de montos, detalles de los conceptos en la factura, y los datos fiscales del emisor y receptor.
#
# 4. Resumen Ejecutivo del Contrato:
# Resumen Ejecutivo:
#
# El presente documento es un contrato de servicios celebrado entre Servicios Tech SA, en adelante "Proveedor", y Empresa ABC, en adelante "Cliente". El acuerdo tiene una duración de 12 meses y establece un valor mensual de $5,000. Los servicios incluidos en este contrato comprenden el mantenimiento y soporte técnico disponible las 24 horas del día, los 7 días de la semana. Este contrato busca garantizar que el Cliente reciba un servicio continuo y de alta calidad, brindando atención inmediata y soluciones efectivas a cualquier problema técnico que pueda surgir durante el periodo acordado. El acuerdo refuerza el compromiso del Proveedor de mantener los sistemas del Cliente operativos y actualizados para asegurar el éxito y la eficiencia operativa de Empresa ABC.
#
# 5. Puntos Clave de la Factura:
# 1. **Número de Factura:** FAC-2023-001
# 2. **Fecha de Emisión:** 20 de Noviembre de 2023
# 3. **Emisor:**
#    - Nombre: Servicios Tech SA
#    - RFC: TECH231120ABC
# 4. **Receptor:**
#    - Nombre: Empresa ABC
#    - RFC: ABC850101XYZ
# 5. **Conceptos Detallados:**
#    - Licencias de Software de Gestión (5 unidades)
#      - Precio unitario: $1,200
#      - Subtotal: $6,000
#    - Servicio de Implementación
#      - Precio: $2,000
# 6. **Totales:**
#    - Subtotal General: $8,000
#    - IVA (16%): $1,280
#    - Total de la Factura: $9,280
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
