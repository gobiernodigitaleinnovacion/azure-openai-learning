# %%
import sys
from pathlib import Path
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from src.ocr_mejorado import OCRMejorado

# Crear instancia
ocr = OCRMejorado()

# Datos de ejemplo
texto_imagen = """
F A C T U R A
No, 1234
Feeha: 15/11/2O23
Cllente: Empr3sa ABC
Total: $ l,234.5O
"""

texto_estructurado = """
CONTRATO DE SERVICIOS
CLÁUSULA PRIMERA: PARTES
1.1 EL PROVEEDOR: Servicios Tech SA
1.2 EL CLIENTE: Empresa ABC

CLÁUSULA SEGUNDA: OBJETO
2.1 Prestación de servicios...
"""

# 1. Extracción y corrección
print("1. Extracción y corrección de texto:")
texto_extraido = ocr.extraer_texto(texto_imagen)
print(texto_extraido)

# 2. Análisis de estructura
print("\n2. Análisis de estructura del documento:")
doc_estructurado = ocr.analizar_estructura(texto_estructurado)
print(doc_estructurado)

# 3. Corrección de errores
print("\n3. Corrección de errores de OCR:")
texto_corregido = ocr.corregir_errores(texto_imagen)
print(texto_corregido)
# Out:
# 1. Extracción y corrección de texto:
# FACTURA
# No. 1234
# Fecha: 15/11/2023
# Cliente: Empresa ABC
# Total: $1,234.50
#
# 2. Análisis de estructura del documento:
# La estructura del documento parece ser la de un contrato formal, con una organización clara y lógica que facilita la comprensión de los términos y condiciones acordados entre las partes involucradas. A continuación, identificaré las secciones y elementos clave observados en el texto proporcionado:
#
# 1. **Título del Documento:**
#    - **"CONTRATO DE SERVICIOS"**: Indica el tipo de documento y su propósito general.
#
# 2. **Secciones del Contrato:**
#    - **CLÁUSULA PRIMERA: PARTES**
#      - **1.1 EL PROVEEDOR:** Servicios Tech SA
#      - **1.2 EL CLIENTE:** Empresa ABC
#      - *Esta sección define quiénes son las partes involucradas en el contrato.*
#
#    - **CLÁUSULA SEGUNDA: OBJETO**
#      - **2.1 Prestación de servicios...**
#      - *Esta sección describe el objeto del contrato, es decir, qué servicios se prestarán. Aunque el extracto no está completo, se anticipa que detallará el alcance y naturaleza de los servicios ofrecidos.*
#
# 3. **Elementos Clave:**
#    - **Enumeración de Cláusulas:** Las cláusulas y subsecciones están numeradas (por ejemplo, 1.1, 1.2, 2.1), lo que sugiere una organización sistemática y facilita la referencia a partes específicas del contrato.
#    - **Identificación de Partes:** Se mencionan claramente las entidades involucradas, proporcionando claridad sobre quiénes son los firmantes y responsables del contrato.
#    - **Propósito y Alcance:** Se insinúa mediante "OBJETO" que se abordará el alcance de los servicios, un componente crucial en cualquier acuerdo de servicio.
#
# Este tipo de estructura es común en contratos, permitiendo una lectura detallada y ordenada del documento, facilitando su interpretación y asegurando que los términos sean claros para todas las partes involucradas. Si el documento es extenso, es posible que haya más cláusulas relativas a aspectos como la duración del contrato, términos de pago, obligaciones de las partes, confidencialidad, etc.
#
# 3. Corrección de errores de OCR:
# FACTURA
# No. 1234
# Fecha: 15/11/2023
# Cliente: Empresa ABC
# Total: $1,234.50
