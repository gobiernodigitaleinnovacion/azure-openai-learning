# %%
import sys
from pathlib import Path
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from src.recomendador import Recomendador

# Crear instancia
recomendador = Recomendador()

# Datos de ejemplo
perfil_usuario = """
Nombre: Ana García
Edad: 28
Intereses: tecnología, viajes, fotografía
Ubicación: Madrid
Presupuesto: Medio
"""

historial = """
Últimas compras:
- Cámara mirrorless entry-level
- Trípode básico
- Curso básico de fotografía online
"""

# 1. Generar recomendaciones
print("1. Recomendaciones Personalizadas:")
recomendaciones = recomendador.generar_recomendaciones(perfil_usuario, historial)
print(recomendaciones)

# 2. Explicar recomendación
print("\n2. Explicación de Recomendación:")
recomendacion_especifica = "Curso avanzado de fotografía digital"
explicacion = recomendador.explicar_recomendacion(recomendacion_especifica, perfil_usuario)
print(explicacion)

# 3. Ajustar basado en feedback
print("\n3. Ajuste de Recomendaciones:")
feedback = "Prefiero contenido más avanzado y menos productos básicos"
ajustes = recomendador.ajustar_recomendaciones(feedback, recomendaciones)
print(ajustes)
# Out:
# 1. Recomendaciones Personalizadas:
# Con base en el perfil y el historial de compras de Ana García, aquí tienes algunas recomendaciones personalizadas:
#
# 1. **Tecnología y Fotografía Avanzada**:
#    - **Objetivos para Cámara**: Considerando que ya adquiriste una cámara mirrorless entry-level, explorar algunos objetivos adicionales podría mejorar significativamente tus habilidades y el resultado de tus fotografías. Investigar lentes que se adapten a diferentes estilos como paisaje o retrato podría ser útil.
#    - **Software de Edición de Fotos**: Programas como Adobe Lightroom o Capture One pueden ayudarte a llevar tus fotos al siguiente nivel. Ambos ofrecen funcionalidades avanzadas de edición que podrías explotar después de completar tu curso básico de fotografía.
# ...
