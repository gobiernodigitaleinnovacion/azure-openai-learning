# %%
import sys
from pathlib import Path
from src.automatizador_workflows import AutomatizadorWorkflows

current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

automatizador = AutomatizadorWorkflows()

print("Diseño de Workflow para Onboarding")
workflow = automatizador.disenar_workflow("Proceso de onboarding de nuevos empleados")
print(workflow)

proceso_actual = """
1. Recepción de documentos del empleado (2 días)
2. Verificación de antecedentes (5 días)
3. Alta en sistemas (1 día)
4. Asignación de equipo (3 días)
5. Capacitación inicial (5 días)
"""
print("Optimización de Proceso")
optimizacion = automatizador.optimizar_proceso(proceso_actual)
print(optimizacion)

metricas = """
Paso 1: 2 días promedio (rango: 1-4 días)
Paso 2: 5 días promedio (rango: 3-8 días)
Paso 3: 1 día promedio (rango: 1-2 días)
Paso 4: 3 días promedio (rango: 2-5 días)
Paso 5: 5 días promedio (rango: 3-7 días)
"""
print("Análisis de Cuellos de Botella")
cuellos_botella = automatizador.identificar_cuellos_botella(metricas)
print(cuellos_botella)
# Out:
# Diseño de Workflow para Onboarding
# El proceso de onboarding de nuevos empleados es crucial para integrar eficazmente a los nuevos miembros del equipo en la organización. A continuación, se presenta un workflow detallado:
#
# ### Etapa 1: Preparación (1-2 semanas antes del primer día)
#
# **Paso 1: Confirmación de empleo**
# - **Rol Responsable:** Recursos Humanos (RR.HH.)
# - **Tiempo Estimado:** 1-2 días
# - **Tareas:**
#   - Enviar la carta de oferta de empleo y recibir la aceptación.
#   - Confirmar fecha de inicio.
#
# **Paso 2: Preparación de documentación**
# - **Rol Responsable:** RR.HH.
# - **Tiempo Estimado:** 2-3 días
# - **Tareas:**
#   - Preparar contratos de trabajo y documentos legales necesarios.
#   - Crear cuenta de correo y acceso a sistemas internos.
#
# **Paso 3: Preparación del espacio de trabajo**
# - **Rol Responsable:** IT y Administración
# - **Tiempo Estimado:** 1 semana
# - **Tareas:**
#   - Configurar computadora, teléfono y otros equipos necesarios.
#   - Asignar espacio físico o configuración remota para home office.
#
# ### Etapa 2: Primer día (Día 1)
#
# **Paso 4: Bienvenida**
# - **Rol Responsable:** Manager directo
# - **Tiempo Estimado:** 1 hora
# - **Tareas:**
#   - Dar la bienvenida en persona o de manera virtual.
#   - Presentación del equipo y tour de la oficina si es presencial.
#
# **Paso 5: Revisión de documentación**
# - **Rol Responsable:** RR.HH.
# - **Tiempo Estimado:** 2 horas
# - **Tareas:**
#   - Firmar contratos y revisión de políticas de la empresa.
#   - Entrega del manual del empleado.
#
# **Paso 6: Configuración técnica**
# - **Rol Responsable:** IT
# - **Tiempo Estimado:** 1 hora
# - **Tareas:**
#   - Asegurar que el nuevo empleado pueda acceder a todas las herramientas y sistemas necesarios.
#   - Solucionar cualquier problema técnico inicial.
#
# ### Etapa 3: Primera semana
#
# **Paso 7: Capacitación inicial**
# - **Rol Responsable:** Manager y equipos específicos
# - **Tiempo Estimado:** 1 semana
# - **Tareas:**
#   - Programar sesiones de capacitación general y específica según el rol.
#   - Asegurar que el nuevo empleado comprende sus responsabilidades.
#
# **Paso 8: Asignación de un mentor**
# - **Rol Responsable:** Manager
# - **Tiempo Estimado:** 1 día (para la selección)
# - **Tareas:**
#   - Asignar un compañero de trabajo que actúe como mentor durante el primer mes.
#   - Facilitar reuniones regulares con el mentor.
#
# ### Etapa 4: Primer mes
#
# **Paso 9: Evaluación de progreso**
# - **Rol Responsable:** Manager
# - **Tiempo Estimado:** Al final del primer mes
# - **Tareas:**
#   - Reunión de feedback para discutir el progreso y resolver dudas.
#   - Ajustes necesarios en tareas o capacitación adicional si es necesario.
#
# ### Etapa 5: Trimestre inicial
#
# **Paso 10: Evaluación final del onboarding**
# - **Rol Responsable:** RR.HH. y Manager
# - **Tiempo Estimado:** Al final del tercer mes
# - **Tareas:**
#   - Realizar una evaluación formal del proceso de onboarding.
#   - Solicitar feedback del nuevo empleado para mejorar futuros procesos de onboarding.
#
# Cada paso del proceso debe incluir comunicación clara entre los departamentos involucrados y el nuevo empleado para asegurar una transición suave y sin problemas. Este workflow garantiza que los nuevos empleados se sientan bienvenidos y equipados para empezar con éxito en sus nuevos roles.
# Optimización de Proceso
# Para optimizar este proceso de incorporación de empleados, debemos buscar reducir tiempos en cada una de las etapas sin comprometer la calidad y seguridad del proceso. Aquí hay algunas sugerencias:
#
# 1. **Recepción de documentos del empleado (2 días)**
#    - **Digitalización del proceso**: Utilizar plataformas digitales para la recepción de documentos, permitiendo a los empleados cargar directamente sus documentos online. Esto podría reducir el tiempo de procesamiento y evitar demoras relacionadas con reenvíos de documentos físicos.
#    - **Checklist clara**: Proveer al empleado un checklist detallado y claro de los documentos necesarios para evitar idas y venidas innecesarias.
#
# 2. **Verificación de antecedentes (5 días)**
#    - **Subcontratación de servicios especializados**: Considerar externalizar esta tarea a empresas especializadas que puedan garantizar tiempos de respuesta más rápidos gracias a sus recursos dedicados.
#    - **Automatización del proceso**: Usar software que agilice la revisión y reconocimiento de antecedentes mediante integraciones con bases de datos oficiales podría reducir significativamente el tiempo.
#    - **Inicio anticipado**: Si es viable, comenzar la verificación de antecedentes antes de la recepción total de los documentos, basándose en información inicial proporcionada por el candidato.
#
# 3. **Alta en sistemas (1 día)**
#    - **Automatización administrativa**: Implementar software que permita el alta masiva y automática de datos de empleados nuevos en los distintos sistemas de la empresa.
#    - **Formulario único de inscripción**: Centralizar la información en un formulario único que se distribuya automáticamente a los sistemas necesarios.
#
# 4. **Asignación de equipo (3 días)**
#    - **Inventario previo y preparación anticipada**: Tener un inventario actualizado y preparar el equipo con antelación podría alinear los tiempos para estar listos incluso antes de la llegada del empleado.
#    - **Listas de verificación digitalizadas**: Implementar listas de verificación digitales para el seguimiento eficiente de la asignación y disponibilidad de equipos.
#
# 5. **Capacitación inicial (5 días)**
#    - **E-learning y módulos online**: Ofrecer la capacitación a través de plataformas de e-learning donde los módulos puedan ser completados a ritmo propio podría acortar el tiempo necesario.
#    - **Capacitación previa o simultánea**: Permitir a los empleados empezar con ciertos módulos de capacitación antes de su ingreso formal o simultáneamente durante otros procesos de onboarding.
#    - **Optimización de contenidos**: Revisar y actualizar el contenido de la capacitación para enfocarse en entregar la información más relevante de la manera más concisa.
#
# Implementar estas optimizaciones puede requerir una inversión inicial en tecnología y cambios de proceso, pero los beneficios en términos de tiempo y eficiencia a largo plazo pueden ser significativos, contribuyendo a una integración más fluida y rápida de los nuevos empleados.
# Análisis de Cuellos de Botella
# A partir de las métricas proporcionadas para cada paso del proceso, se pueden identificar posibles cuellos de botella y problemas que podrían estar afectando la eficiencia general. Aquí tienes el análisis:
#
# 1. **Paso 2 y Paso 5 como cuellos de botella potenciales:**
#    - **Paso 2** tiene un promedio de finalización de 5 días, con un rango que puede extenderse hasta 8 días. Este es el paso que toma más tiempo en promedio, lo cual indica que podría ser un cuello de botella. Las variaciones también son más amplias comparado con otros pasos, lo que sugiere que podría haber inconsistencias o problemas que a menudo retrasan este paso.
#    - **Paso 5** también toma un promedio de 5 días, y aunque su rango máximo es de 7 días (un poco menor que Paso 2), sigue siendo un tiempo considerable dentro del proceso total. Esto sugiere que, al igual que Paso 2, puede ser un área que necesite más atención para mejorar la eficiencia.
#
# 2. **Problemas potenciales:**
#    - **Variabilidad en los tiempos del Paso 2 y Paso 5:** La amplia variabilidad de tiempo en estos pasos puede indicar problemas de recursos, como falta de personal o herramientas inadecuadas, que deberían investigarse.
#    - **Complejidad o necesidad de optimización:** Si estos pasos son más complejos, podría ser necesario descomponerlos en subprocesos más manejables, o tal vez se necesitan capacitaciones adicionales para el personal.
#    - **Dependencias externas:** Puede haber factores externos que afectan el tiempo de procesamiento en estos pasos específicos, como dependencias de terceros, que deberían ser revisadas para garantizar que estén optimizadas.
#
# 3. **Eficiencia en otros pasos:**
#    - **Paso 1 y Paso 3** son los más rápidos, con tiempos promedios de 2 y 1 día respectivamente, y rangos bastante estrechos. Esto sugiere que estos pasos están funcionando de manera eficiente y no parecen contribuir a ningún retraso significativo del proceso.
#    - **Paso 4** tiene un promedio de 3 días con un rango de 2 a 5 días; aunque no es tan largo como los pasos 2 y 5, todavía tiene potencial para mejoras dependiendo de la importancia de los tiempos de ciclo para el negocio.
#
# En resumen, para mejorar el proceso en su conjunto, se debería investigar más detalladamente los pasos 2 y 5 para identificar las causas de las variaciones y posibles cuellos de botella, con el fin de implementar soluciones que mejoren la eficiencia y reduzcan el tiempo de procesamiento.
