# %%
import sys
from pathlib import Path
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from src.asistente_codigo import AsistenteCodigo

# Crear instancia
asistente = AsistenteCodigo()

# 1. Generar código
print("1. Generación de Código:")
descripcion = "Crear una clase Calculadora que tenga métodos para sumar, restar, multiplicar y dividir"
codigo_generado = asistente.generar_codigo(descripcion)
print(codigo_generado)

# 2. Explicar código
print("\n2. Explicación de Código:")
codigo_ejemplo = """
def quicksort(arr):
   if len(arr) <= 1:
       return arr
   pivot = arr[len(arr) // 2]
   left = [x for x in arr if x < pivot]
   middle = [x for x in arr if x == pivot]
   right = [x for x in arr if x > pivot]
   return quicksort(left) + middle + quicksort(right)
"""
explicacion = asistente.explicar_codigo(codigo_ejemplo)
print(explicacion)

# 3. Sugerir mejoras
print("\n3. Sugerencias de Mejora:")
codigo_mejorable = """
def calc_average(l):
   s = 0
   for i in range(len(l)):
       s += l[i]
   return s/len(l)
"""
sugerencias = asistente.sugerir_mejoras(codigo_mejorable)
print(sugerencias)
# Out:
# 1. Generación de Código:
# ```python
# class Calculadora:
#     """
#     Una clase simple para realizar operaciones aritméticas básicas.
#
#     Métodos:
#     --------
#     sumar(a, b)
#         Retorna la suma de a y b.
#
#     restar(a, b)
#         Retorna la diferencia cuando b es restado de a.
#
#     multiplicar(a, b)
#         Retorna el producto de a y b.
#
#     dividir(a, b)
#         Retorna el cociente de a dividido por b. Lanza una excepción si b es 0.
#     """
#
#     def sumar(self, a: float, b: float) -> float:
#         """
#         Suma dos números.
#
#         Parámetros:
#         a : float
#             El primer número a sumar.
#         b : float
#             El segundo número a sumar.
#
#         Retorna:
#         float
#             La suma de los dos números.
#         """
#         return a + b
#
#     def restar(self, a: float, b: float) -> float:
#         """
#         Resta el segundo número del primero.
#
#         Parámetros:
# ...
