# %%
import sys
from pathlib import Path
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from src.analisis_predictivo import AnalizadorPredictivo

# Crear instancia
analizador = AnalizadorPredictivo()

# Datos de ejemplo
datos_ventas = """
2023-01: 100000
2023-02: 120000
2023-03: 150000
2023-04: 140000
2023-05: 180000
2023-06: 200000
"""

# 1. Predicción de tendencias
print("1. Predicción de Tendencias:")
prediccion = analizador.predecir_tendencia(
   datos_ventas,
   "Ventas mensuales de software empresarial"
)
print(prediccion)

# 2. Análisis de patrones
print("\n2. Análisis de Patrones:")
patrones = analizador.analizar_patrones(datos_ventas, "mensual")
print(patrones)

# 3. Recomendaciones
print("\n3. Recomendaciones Estratégicas:")
recomendaciones = analizador.generar_recomendaciones(patrones)
print(recomendaciones)
# Out:
# 1. Predicción de Tendencias:
# Basado en los datos históricos proporcionados, vamos a analizar las ventas mensuales de software empresarial para identificar patrones y predecir tendencias futuras.
#
# **Análisis de los datos:**
#
# 1. **Patrones de Crecimiento:**
#    - De enero a febrero, las ventas aumentaron de 100,000 a 120,000, lo que representa un aumento del 20%.
#    - De febrero a marzo, las ventas aumentaron de 120,000 a 150,000, un aumento del 25%.
#    - De marzo a abril, las ventas disminuyeron de 150,000 a 140,000, una caída del 6.67%.
#    - De abril a mayo, las ventas aumentaron de 140,000 a 180,000, un aumento del 28.57%.
#    - De mayo a junio, las ventas aumentaron de 180,000 a 200,000, un aumento del 11.11%.
#
# 2. **Tendencias Observadas:**
#    - Aparte de una caída entre marzo y abril, las ventas han mostrado un crecimiento consistente.
# ...
