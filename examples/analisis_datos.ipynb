# %%
# Análisis de Datos con Azure OpenAI

import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(''))))

from src.analizador_datos import AnalizadorDatos

# Ejemplo de datos
datos_metricas = """
Métricas de Ventas 2023:
- Ventas Q1: $150,000
- Ventas Q2: $180,000
- Ventas Q3: $220,000
- Ventas Q4: $250,000
- Tasa de conversión: 2.5%
- Clientes nuevos: 1,200
"""

# Crear el analizador
analizador = AnalizadorDatos()

# 1. Interpretación de métricas
interpretacion = analizador.interpretar_metricas(datos_metricas)
print("Interpretación de Métricas:")
print(interpretacion)

# 2. Análisis de tendencias
tendencias = analizador.analizar_tendencias(datos_metricas)
print("\nAnálisis de Tendencias:")
print(tendencias)

# 3. Recomendaciones
recomendaciones = analizador.generar_recomendaciones(datos_metricas)
print("\nRecomendaciones:")
print(recomendaciones)
# Out:
# Interpretación de Métricas:
# Las métricas de ventas de 2023 muestran un crecimiento estable y positivo a lo largo del año. En el primer trimestre (Q1), las ventas fueron de $150,000, incrementándose a $180,000 en el segundo trimestre (Q2), lo que representa un aumento del 20%. El tercer trimestre (Q3) reflejó una mayor aceleración en las ventas, alcanzando los $220,000, un incremento del 22.2% respecto al trimestre anterior. Finalmente, en el cuarto trimestre (Q4), las ventas fueron de $250,000, lo que representa un crecimiento adicional del 13.6% desde el tercer trimestre. Este aumento progresivo sugiere un buen rendimiento de mercado y posiblemente mejoras en estrategias comerciales o de marketing.
#
# La tasa de conversión es del 2.5%, lo que indica que de cada 100 visitantes o potenciales clientes, aproximadamente 2.5 realizan una compra. Esta tasa es crucial para evaluar la efectividad de la estrategia de captación de ventas.
#
# ...
